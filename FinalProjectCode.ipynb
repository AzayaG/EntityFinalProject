# %%
#Step 1 is to load in the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox
from pylab import *

# %%
# WEEK2 
# DATA WRANGLING

# %%
#Loading the data in MATH
math = pd.read_csv('/Users/agombodorj/Desktop/pisamath.csv')
pd.read_csv('/Users/agombodorj/Desktop/pisamath.csv')
math.head(100)
# Out:
#    LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME    Value  Flag Codes
# 0       AUS  PISAMATH     BOY  MEANSCORE         A  2003  527.000         NaN
# 1       AUS  PISAMATH     BOY  MEANSCORE         A  2006  527.000         NaN
# 2       AUS  PISAMATH     BOY  MEANSCORE         A  2009  519.000         NaN
# 3       AUS  PISAMATH     BOY  MEANSCORE         A  2012  510.115         NaN
# 4       AUS  PISAMATH     BOY  MEANSCORE         A  2015  497.000         NaN
# ..      ...       ...     ...        ...       ...   ...      ...         ...
# 95      DEU  PISAMATH     BOY  MEANSCORE         A  2006  513.000         NaN
# 96      DEU  PISAMATH     BOY  MEANSCORE         A  2009  520.000         NaN
# 97      DEU  PISAMATH     BOY  MEANSCORE         A  2012  520.190         NaN
# 98      DEU  PISAMATH     BOY  MEANSCORE         A  2015  514.000         NaN
# 99      DEU  PISAMATH     BOY  MEANSCORE         A  2018  503.000         NaN
#
# [100 rows x 8 columns]

# %%
math.shape
# Out:
# (464, 8)

# %%
math.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
math.rename(columns={'Value':'SCORE','LOCATION':'COUNTRY', 'TIME':'YEAR'}, inplace=True)
math.head(5)
# Out:
#   COUNTRY INDICATOR SUBJECT    MEASURE FREQUENCY  YEAR    SCORE  Flag Codes
# 0     AUS  PISAMATH     BOY  MEANSCORE         A  2003  527.000         NaN
# 1     AUS  PISAMATH     BOY  MEANSCORE         A  2006  527.000         NaN
# 2     AUS  PISAMATH     BOY  MEANSCORE         A  2009  519.000         NaN
# 3     AUS  PISAMATH     BOY  MEANSCORE         A  2012  510.115         NaN
# 4     AUS  PISAMATH     BOY  MEANSCORE         A  2015  497.000         NaN

# %%
math.shape
# Out:
# (464, 8)

# %%
# GROUP BY - Aggregating data 

# THE LOWEST SCORE IN MATH 

math.groupby('SUBJECT')['SCORE'].min()
# Out:
# SUBJECT
# BOY     362.0
# GIRL    348.0
# Name: SCORE, dtype: float64

# %%
# GROUP BY - Aggregating data 

# THE highest SCORE IN MATH 

math.groupby('SUBJECT')['SCORE'].max()
# Out:
# SUBJECT
# BOY     564.0
# GIRL    564.0
# Name: SCORE, dtype: float64

# %%
math.COUNTRY.value_counts()
# Out:
# DNK     12
# NZL     12
# NOR     12
# ITA     12
# ESP     12
# LUX     12
# TUR     12
# NLD     12
# GRC     12
# ISL     12
# FRA     12
# CAN     12
# DEU     12
# MEX     12
# FIN     12
# SWE     12
# OAVG    12
# POL     12
# AUS     12
# USA     12
# SVK     12
# IRL     12
# BEL     12
# PRT     12
# BRA     12
# IDN     12
# CZE     12
# HUN     12
# JPN     12
# KOR     12
# CHE     12
# EST     10
# CHL     10
# ISR     10
# RUS     10
# SVN     10
# AUT     10
# GBR     10
# COL      4
# LVA      4
# LTU      2
# SGP      2
# HKG      2
# MAC      2
# PER      2
# TWN      2
# CRI      2
# Name: COUNTRY, dtype: int64

# %%
#Filtering the chosen countries and years for the project 

recode_math =(
    math
    .filter(items = ["COUNTRY", "INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY", "YEAR", "SCORE"])
     .sort_values("YEAR")
    .query("YEAR == 2012 |YEAR == 2015 |YEAR == 2018 ")
    .query("COUNTRY == 'AUS' | COUNTRY == 'MEX' | COUNTRY == 'LUX' | COUNTRY == 'KOR' | COUNTRY == 'JAP' | COUNTRY == 'TUR' | COUNTRY == 'USA' ")
    .head(50)
)

# %%
recode_math.shape
# Out:
# (36, 7)

# %%
recode_math
# Out:
#     COUNTRY INDICATOR SUBJECT    MEASURE FREQUENCY  YEAR    SCORE
# 325     TUR  PISAMATH     BOY  MEANSCORE         A  2012  451.934
# 9       AUS  PISAMATH    GIRL  MEANSCORE         A  2012  497.821
# 347     USA  PISAMATH     BOY  MEANSCORE         A  2012  483.647
# 187     KOR  PISAMATH    GIRL  MEANSCORE         A  2012  544.193
# 199     LUX  PISAMATH    GIRL  MEANSCORE         A  2012  477.117
# 211     MEX  PISAMATH    GIRL  MEANSCORE         A  2012  406.427
# 181     KOR  PISAMATH     BOY  MEANSCORE         A  2012  562.114
# 205     MEX  PISAMATH     BOY  MEANSCORE         A  2012  420.411
# 353     USA  PISAMATH    GIRL  MEANSCORE         A  2012  478.995
# 3       AUS  PISAMATH     BOY  MEANSCORE         A  2012  510.115
# 331     TUR  PISAMATH    GIRL  MEANSCORE         A  2012  443.948
# 193     LUX  PISAMATH     BOY  MEANSCORE         A  2012  502.193
# 4       AUS  PISAMATH     BOY  MEANSCORE         A  2015  497.000
# ...

# %%
recode_math.groupby('SUBJECT')['SCORE'].max()
# Out:
# SUBJECT
# BOY     562.114
# GIRL    544.193
# Name: SCORE, dtype: float64

# %%
recode_math.groupby('SUBJECT')['SCORE'].min()
# Out:
# SUBJECT
# BOY     412.0
# GIRL    403.0
# Name: SCORE, dtype: float64

# %%
#LOADING THE DATA IN READING
reading = pd.read_csv('/Users/agombodorj/Desktop/pisareading.csv')
pd.read_csv('/Users/agombodorj/Desktop/pisareading.csv')
reading.head()
# Out:
#   LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME   Value  Flag Codes
# 0      AUS  PISAREAD     BOY  MEANSCORE         A  2000  513.00         NaN
# 1      AUS  PISAREAD     BOY  MEANSCORE         A  2003  506.00         NaN
# 2      AUS  PISAREAD     BOY  MEANSCORE         A  2006  495.00         NaN
# 3      AUS  PISAREAD     BOY  MEANSCORE         A  2009  496.00         NaN
# 4      AUS  PISAREAD     BOY  MEANSCORE         A  2012  495.09         NaN

# %%
reading.rename(columns={'Value':'SCORE','LOCATION':'COUNTRY', 'TIME':'YEAR'}, inplace=True)
reading.head(50)
# Out:
#    COUNTRY INDICATOR SUBJECT    MEASURE FREQUENCY  YEAR    SCORE  Flag Codes
# 0      AUS  PISAREAD     BOY  MEANSCORE         A  2000  513.000         NaN
# 1      AUS  PISAREAD     BOY  MEANSCORE         A  2003  506.000         NaN
# 2      AUS  PISAREAD     BOY  MEANSCORE         A  2006  495.000         NaN
# 3      AUS  PISAREAD     BOY  MEANSCORE         A  2009  496.000         NaN
# 4      AUS  PISAREAD     BOY  MEANSCORE         A  2012  495.090         NaN
# 5      AUS  PISAREAD     BOY  MEANSCORE         A  2015  487.000         NaN
# 6      AUS  PISAREAD     BOY  MEANSCORE         A  2018  487.000         NaN
# 7      AUS  PISAREAD    GIRL  MEANSCORE         A  2000  546.000         NaN
# 8      AUS  PISAREAD    GIRL  MEANSCORE         A  2003  545.000         NaN
# 9      AUS  PISAREAD    GIRL  MEANSCORE         A  2006  532.000         NaN
# 10     AUS  PISAREAD    GIRL  MEANSCORE         A  2009  533.000         NaN
# ...

# %%
reading.shape
# Out:
# (787, 8)

# %%
reading.columns
# Out:
# Index(['COUNTRY', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'YEAR',
#        'SCORE', 'Flag Codes'],
#       dtype='object')

# %%
# How many columns and rows in reading data
reading.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 787 entries, 0 to 786
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   COUNTRY     787 non-null    object
#  1   INDICATOR   787 non-null    object
#  2   SUBJECT     787 non-null    object
#  3   MEASURE     787 non-null    object
#  4   FREQUENCY   787 non-null    object
#  5   YEAR        787 non-null    int64
#  6   SCORE       787 non-null    float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 49.3+ KB

# %%
# THE LOWEST SCORE IN READING
reading.groupby('SUBJECT')['SCORE'].min()
# Out:
# SUBJECT
# BOY     358.0
# GIRL    380.0
# TOT     371.0
# Name: SCORE, dtype: float64

# %%
# THE HIGHEST SCORE IN READING
reading.groupby('SUBJECT')['SCORE'].max()
# Out:
# SUBJECT
# BOY     539.0
# GIRL    574.0
# TOT     556.0
# Name: SCORE, dtype: float64

# %%
# How many countries in included in the reading data 

reading.COUNTRY.value_counts()
# Out:
# DNK     21
# NZL     21
# CAN     21
# ISL     21
# GRC     21
# ITA     21
# AUS     21
# BRA     21
# IDN     21
# PRT     21
# BEL     21
# POL     21
# FIN     21
# JPN     21
# SWE     21
# MEX     21
# NOR     21
# CZE     21
# HUN     21
# IRL     21
# KOR     21
# CHE     21
# FRA     21
# DEU     21
# LUX     20
# RUS     19
# USA     18
# CHL     18
# ISR     18
# NLD     18
# SVK     18
# TUR     18
# AUT     18
# ESP     18
# OAVG    17
# EST     15
# SVN     15
# GBR     15
# LVA     11
# COL      6
# HKG      3
# LTU      3
# MAC      3
# PER      3
# TWN      3
# SGP      3
# CRI      3
# Name: COUNTRY, dtype: int64

# %%
#Filtering the chosen countries and years for the project 
recode_reading =(
    reading
    .filter(items = ["COUNTRY", "INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY", "YEAR", "SCORE"])
     .sort_values("YEAR")
    .query("YEAR == 2012 |YEAR == 2015 |YEAR == 2018 ")
    .query("COUNTRY == 'AUS' | COUNTRY == 'MEX' | COUNTRY == 'LUX' | COUNTRY == 'KOR' | COUNTRY == 'JAP' | COUNTRY == 'TUR' | COUNTRY == 'USA' ")
    .head()
)

# %%
recode_reading.groupby('SUBJECT')['SCORE'].max()
# Out:
# SUBJECT
# BOY     452.843
# GIRL    529.542
# TOT     512.000
# Name: SCORE, dtype: float64

# %%
recode_reading.groupby('SUBJECT')['SCORE'].min()
# Out:
# SUBJECT
# BOY     452.843
# GIRL    435.272
# TOT     475.000
# Name: SCORE, dtype: float64

# %%
#Loading the data in SCIENCE
science = pd.read_csv('/Users/agombodorj/Desktop/pisascience.csv')
pd.read_csv('/Users/agombodorj/Desktop/pisascience.csv')
science.head()
# Out:
#   LOCATION    INDICATOR SUBJECT    MEASURE FREQUENCY  TIME    Value  \
# 0      AUS  PISASCIENCE     BOY  MEANSCORE         A  2006  527.000
# 1      AUS  PISASCIENCE     BOY  MEANSCORE         A  2009  527.000
# 2      AUS  PISASCIENCE     BOY  MEANSCORE         A  2012  523.728
# 3      AUS  PISASCIENCE     BOY  MEANSCORE         A  2015  511.000
# 4      AUS  PISASCIENCE     BOY  MEANSCORE         A  2018  504.000
#
#    Flag Codes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
science.shape
# Out:
# (600, 8)

# %%
science.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
# How many columns and rows in science data
science.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    600 non-null    object
#  1   INDICATOR   600 non-null    object
#  2   SUBJECT     600 non-null    object
#  3   MEASURE     600 non-null    object
#  4   FREQUENCY   600 non-null    object
#  5   TIME        600 non-null    int64
#  6   Value       600 non-null    float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 37.6+ KB

# %%
science.rename(columns={'Value':'SCORE','LOCATION':'COUNTRY', 'TIME':'YEAR'}, inplace=True)
science.head(5)
# Out:
#   COUNTRY    INDICATOR SUBJECT    MEASURE FREQUENCY  YEAR    SCORE  Flag Codes
# 0     AUS  PISASCIENCE     BOY  MEANSCORE         A  2006  527.000         NaN
# 1     AUS  PISASCIENCE     BOY  MEANSCORE         A  2009  527.000         NaN
# 2     AUS  PISASCIENCE     BOY  MEANSCORE         A  2012  523.728         NaN
# 3     AUS  PISASCIENCE     BOY  MEANSCORE         A  2015  511.000         NaN
# 4     AUS  PISASCIENCE     BOY  MEANSCORE         A  2018  504.000         NaN

# %%
# THE LOWEST SCORE IN SCIENCE
science.groupby('SUBJECT')['SCORE'].min()
# Out:
# SUBJECT
# BOY     378.000
# GIRL    383.459
# TOT     382.000
# Name: SCORE, dtype: float64

# %%
# THE HIGHEST SCORE IN SCIENCE
science.groupby('SUBJECT')['SCORE'].max()
# Out:
# SUBJECT
# BOY     562.0
# GIRL    565.0
# TOT     563.0
# Name: SCORE, dtype: float64

# %%
# How many countries in included in the reading data 

science.COUNTRY.value_counts()
# Out:
# DNK     15
# AUS     15
# ITA     15
# ESP     15
# LUX     15
# TUR     15
# NLD     15
# GRC     15
# NZL     15
# ISL     15
# CAN     15
# DEU     15
# SVN     15
# MEX     15
# FIN     15
# SWE     15
# EST     15
# OAVG    15
# POL     15
# NOR     15
# USA     15
# FRA     15
# HUN     15
# BEL     15
# PRT     15
# BRA     15
# GBR     15
# ISR     15
# IDN     15
# JPN     15
# SVK     15
# CHL     15
# CZE     15
# IRL     15
# KOR     15
# CHE     15
# RUS     12
# AUT     12
# LVA      9
# COL      6
# MAC      3
# HKG      3
# TWN      3
# LTU      3
# PER      3
# SGP      3
# CRI      3
# Name: COUNTRY, dtype: int64

# %%
#Filtering the chosen countries and years for the project 
recode_science =(
    science
    .filter(items = ["COUNTRY", "INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY", "YEAR", "SCORE"])
     .sort_values("YEAR")
    .query("YEAR == 2012 |YEAR == 2015 |YEAR == 2018 ")
    .query("COUNTRY == 'AUS' | COUNTRY == 'MEX' | COUNTRY == 'LUX' | COUNTRY == 'KOR' | COUNTRY == 'JAP' | COUNTRY == 'TUR' | COUNTRY == 'USA' ")
    .head(20)
)

# %%
recode_science
# Out:
#     COUNTRY    INDICATOR SUBJECT    MEASURE FREQUENCY  YEAR    SCORE
# 295     USA  PISASCIENCE    GIRL  MEANSCORE         A  2012  498.325
# 382     AUS  PISASCIENCE     TOT  MEANSCORE         A  2012  521.000
# 466     MEX  PISASCIENCE     TOT  MEANSCORE         A  2012  415.000
# 461     LUX  PISASCIENCE     TOT  MEANSCORE         A  2012  491.000
# 456     KOR  PISASCIENCE     TOT  MEANSCORE         A  2012  538.000
# 290     USA  PISASCIENCE     BOY  MEANSCORE         A  2012  496.529
# 155     KOR  PISASCIENCE    GIRL  MEANSCORE         A  2012  535.930
# 160     LUX  PISASCIENCE     BOY  MEANSCORE         A  2012  498.715
# 165     LUX  PISASCIENCE    GIRL  MEANSCORE         A  2012  483.484
# 170     MEX  PISASCIENCE     BOY  MEANSCORE         A  2012  418.128
# 2       AUS  PISASCIENCE     BOY  MEANSCORE         A  2012  523.728
# 175     MEX  PISASCIENCE    GIRL  MEANSCORE         A  2012  411.836
# 7       AUS  PISASCIENCE    GIRL  MEANSCORE         A  2012  519.124
# ...

# %%
recode_science.groupby('SUBJECT')['SCORE'].max()
# Out:
# SUBJECT
# BOY     539.408
# GIRL    535.930
# TOT     538.000
# Name: SCORE, dtype: float64

# %%
recode_science.groupby('SUBJECT')['SCORE'].min()
# Out:
# SUBJECT
# BOY     418.128
# GIRL    411.836
# TOT     415.000
# Name: SCORE, dtype: float64

# %%
recode_science.to_csv("recode_science.csv", index=False)

# %%
recode_math.to_csv("recode_math.csv", index=False)

# %%
recode_reading.to_csv("recode_reading.csv", index=False)

# %%
#Loading the data in Educational spendings 
Spendings = pd.read_csv('/Users/agombodorj/Downloads/Spending.csv')  
pd.read_csv('/Users/agombodorj/Downloads/Spending.csv')
Spendings.head(100)
# Out:
#    LOCATION INDICATOR SUBJECT      MEASURE FREQUENCY  TIME     Value  \
# 0       AUT    EDUEXP     TRY  USD_STUDENT         A  2012  16475.70
# 1       AUT    EDUEXP     TRY  USD_STUDENT         A  2013  16853.00
# 2       AUT    EDUEXP     TRY  USD_STUDENT         A  2014  16867.62
# 3       AUT    EDUEXP     TRY  USD_STUDENT         A  2015  17560.62
# 4       AUT    EDUEXP     TRY  USD_STUDENT         A  2016  18625.00
# ..      ...       ...     ...          ...       ...   ...       ...
# 95      AUS    EDUEXP     TRY  USD_STUDENT         A  2012  16002.71
# 96      AUS    EDUEXP     TRY  USD_STUDENT         A  2013  18252.76
# 97      AUS    EDUEXP     TRY  USD_STUDENT         A  2014  19493.58
# 98      AUS    EDUEXP     TRY  USD_STUDENT         A  2015  20304.37
# 99      AUS    EDUEXP     TRY  USD_STUDENT         A  2016  16181.19
#
#     Flag Codes
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 95         NaN
# ...

# %%
#Filtering the chosen countries and years for the project 
recode_spending =(
    Spendings
    .filter(items = ["LOCATION", "INDICATOR", "SUBJECT", "MEASURE", "FREQUENCY", "TIME", "VALUE"])
     .sort_values("TIME")
    .query("TIME == 2012 |TIME == 2015 |TIME == 2018 ")
    .query("LOCATION == 'AUS' | LOCATION == 'MEX' | LOCATION == 'LUX' | LOCATION == 'KOR' | LOCATION == 'JAP' | LOCATION == 'TUR' | LOCATION == 'USA' ")
    .head(6)
)

# %%
recode_spending.to_csv("recode_spending.csv", index=False)

# %%
#Loading the data in 
GDP = pd.read_csv('/Users/agombodorj/Desktop/GDP.csv')  
pd.read_csv('/Users/agombodorj/Desktop/GDP.csv')
GDP.head(10)
# Out:
#              Series Name        Series Code         Country Name Country Code  \
# 0  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG          Afghanistan          AFG
# 1  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG              Albania          ALB
# 2  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG              Algeria          DZA
# 3  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG       American Samoa          ASM
# 4  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG              Andorra          AND
# 5  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG               Angola          AGO
# 6  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG  Antigua and Barbuda          ATG
# 7  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG            Argentina          ARG
# 8  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG              Armenia          ARM
# 9  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG                Aruba          ABW
#
#        1990 [YR1990]      2000 [YR2000]      2012 [YR2012]  \
# ...

# %%
#Filtering the chosen countries and years for the project 
recode_GDP =(
    GDP
    .filter(items = ["Series.name", "Country.name", "2012", "2015", "2018"])
    .query("Country.name == 'AUS' | Country.name == 'MEX' | Country.name == 'LUX' | Country.name == 'KOR' | Country.name == 'JAP' | Country.name == 'TUR' | Country.name == 'USA' ")
    .head(6)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     200             if self.has_resolvers:
# --> 201                 return self.resolvers[key]
#     202
#
# ~/opt/anaconda3/lib/python3.8/collections/__init__.py in __getitem__(self, key)
#     897                 pass
# --> 898         return self.__missing__(key)            # support subclasses that define __missing__
#     899
#
# ~/opt/anaconda3/lib/python3.8/collections/__init__.py in __missing__(self, key)
#     889     def __missing__(self, key):
# --> 890         raise KeyError(key)
#     891
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
